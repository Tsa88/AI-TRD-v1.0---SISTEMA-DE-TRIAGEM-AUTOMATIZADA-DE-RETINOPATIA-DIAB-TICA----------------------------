# %% [markdown]
# <a href="https://colab.research.google.com/github/Tsa88/AI-TRD-v1.0---SISTEMA-DE-TRIAGEM-AUTOMATIZADA-DE-RETINOPATIA-DIAB-TICA----------------------------/blob/main/MatrizAlbuquerque_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googlesearch-python pandas

# %%
# Instale a biblioteca se ainda não tiver
# !pip install python-telegram-bot

from telegram import Bot
import asyncio

# Cole aqui o Token que o BotFather te deu
TOKEN ="8631408825:AAFqjMcF9L-0Ga4_wg5ZA0yWYA6b3v6Jy3w"

async def listar_mensagens():
    bot = Bot(token=TOKEN)
    # Aqui o bot pode ler mensagens de um canal onde ele foi adicionado como administrador
    # Nota: bots não leem mensagens de canais privados automaticamente sem permissão
    print("Conectado com sucesso ao Bot!")

# Execução
await listar_mensagens()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.3/737.3 kB 32.8 MB/s eta 0:00:00
# ...
# Conectado com sucesso ao Bot!

# %%
# 1. Instala o túnel da Cloudflare
# !curl -fsSL https://bin.equinox.io/c/4VmDzA7iaHb/cloudflared-stable-linux-amd64.tgz | tar xz
# !./cloudflared tunnel --url http://localhost:8501 &

# 2. Roda o Streamlit
# !streamlit run app.py &>/dev/null &
# Out:
# /bin/bash: line 1: ./cloudflared: No such file or directory
